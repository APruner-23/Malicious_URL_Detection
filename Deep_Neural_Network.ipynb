# %% [markdown]
# <a href="https://colab.research.google.com/github/APruner-23/Malicious_URL_Detection/blob/main/Deep_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Neural Network for detecting Malicious URLs
#
# In this Colab Notebook we create a model with Tensorflow and evaluate its performances on detecting Malicious URLs

# %%
# Imports
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset csv file located in the Github Repository
# https://github.com/APruner-23/Malicious_URL_Detection.git

dataset_file_link = 'https://raw.githubusercontent.com/APruner-23/Malicious_URL_Detection/main/updated_malicious_phish_with_tld.csv'
urldata = pd.read_csv(dataset_file_link)

# %%
# Check the first 5 elements in the dataset
urldata.head()
# Out:
#                                                  url        type  url_length  \
# 0                                   br-icloud.com.br    phishing          16
# 1                mp3raid.com/music/krizz_kaliko.html      benign          35
# 2                    bopsecrets.org/rexroth/cr/1.htm      benign          31
# 3  http://www.garage-pirenne.be/index.php?option=...  defacement          88
# 4  http://adventure-nicaragua.net/index.php?optio...  defacement         235
#
#    hostname_length  path_length  fd_length  tld_dangerosity  count-  count@  \
# 0                0           16          0              3.0       1       0
# 1                0           35          5              3.0       0       0
# 2                0           31          7              3.0       0       0
# 3               21           10          9              2.0       1       0
# 4               23           10          9              3.0       1       0
#
#    count?  ...  count.  count=  count-http  count-https  count-www  \
# 0       0  ...       2       0           0            0          0
# 1       0  ...       2       0           0            0          0
# 2       0  ...       2       0           0            0          0
# 3       1  ...       3       4           1            0          1
# 4       1  ...       2       3           1            0          0
#
#    count-digits  count-letters  count_dir  use_of_ip  short_url
# 0             0             13          0          1          1
# 1             1             29          2          1          1
# 2             1             25          3          1          1
# 3             7             63          1          1          1
# 4            22            199          1          1          1
#
# [5 rows x 21 columns]

# %%
print(urldata['type'].unique())
# Out:
# ['phishing' 'benign' 'defacement' 'malware']

# %%
urldata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651191 entries, 0 to 651190
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              651191 non-null  object
#  1   type             651191 non-null  object
#  2   url_length       651191 non-null  int64
#  3   hostname_length  651191 non-null  int64
#  4   path_length      651191 non-null  int64
#  5   fd_length        651191 non-null  int64
#  6   tld_dangerosity  651191 non-null  float64
#  7   count-           651191 non-null  int64
#  8   count@           651191 non-null  int64
#  9   count?           651191 non-null  int64
#  10  count%           651191 non-null  int64
#  11  count.           651191 non-null  int64
#  12  count=           651191 non-null  int64
#  13  count-http       651191 non-null  int64
#  14  count-https      651191 non-null  int64
#  15  count-www        651191 non-null  int64
#  16  count-digits     651191 non-null  int64
#  17  count-letters    651191 non-null  int64
#  18  count_dir        651191 non-null  int64
#  19  use_of_ip        651191 non-null  int64
#  20  short_url        651191 non-null  int64
# dtypes: float64(1), int64(18), object(2)
# memory usage: 104.3+ MB

# %%
class_dictionary = {
    'phishing': 0,
    'benign': 1,
    'defacement': 2,
    'malware': 3,
}

# %%
# After dataset split, remember to also split those 2 arrays
# Creation of y array
y = urldata['type'].map(class_dictionary).values
# Convert to a numpy array
#y = np.array(labels)
urls = [url for url in urldata['url']]

# Check % of each class
# Count the total number of rows
total_rows = len(urldata)

phishing_count = urldata[urldata['type'] == 'phishing'].shape[0]
benign_count = urldata[urldata['type'] == 'benign'].shape[0]
defacement_count = urldata[urldata['type'] == 'defacement'].shape[0]
malware_count = urldata[urldata['type'] == 'malware'].shape[0]

# Calculate the percentages
phishing_percentage = (phishing_count / total_rows) * 100
benign_percentage = (benign_count / total_rows) * 100
defacement_percentage = (defacement_count / total_rows) * 100
malware_percentage = (malware_count / total_rows) * 100

print(f"Number of phishing URLs: {phishing_count}")
print(f"Percentage of phishing URLs: {phishing_percentage:.2f}%")
print(f"Number of benign URLs: {benign_count}")
print(f"Percentage of benign URLs: {benign_percentage:.2f}%")
print(f"Number of defacement URLs: {defacement_count}")
print(f"Percentage of defacement URLs: {defacement_percentage:.2f}%")
print(f"Number of malware URLs: {malware_count}")
print(f"Percentage of malware URLs: {malware_percentage:.2f}%")

# Now i can drop url and type
urldata = urldata.drop(columns=['type', 'url'])

# Create x matrix
x = urldata.values
# Out:
# Number of phishing URLs: 94111
# Percentage of phishing URLs: 14.45%
# Number of benign URLs: 428103
# Percentage of benign URLs: 65.74%
# Number of defacement URLs: 96457
# Percentage of defacement URLs: 14.81%
# Number of malware URLs: 32520
# Percentage of malware URLs: 4.99%

# %%
# Check if everything went well during data manipulation

# Should be numpy.ndarray
print("X type: ", type(x))
print('Y type: ', type(y))
print("Urls list type: ", type(urls))

# Should be (651191, 19) and (651191,)
print("X Shape: ", x.shape)
print("Y Shape: ", y.shape)
print("Urls length: ", len(urls))

# Check if they are correct based on the urldata.head()
print("Y: ", y[0:5])
print("X: ", x[0:5])
print("Urls: ", urls[0:5])
# Out:
# X type:  <class 'numpy.ndarray'>
# Y type:  <class 'numpy.ndarray'>
# Urls list type:  <class 'list'>
# X Shape:  (651191, 19)
# Y Shape:  (651191,)
# Urls length:  651191
# Y:  [0 1 1 2 2]
# X:  [[ 16.   0.  16.   0.   3.   1.   0.   0.   0.   2.   0.   0.   0.   0.
#     0.  13.   0.   1.   1.]
#  [ 35.   0.  35.   5.   3.   0.   0.   0.   0.   2.   0.   0.   0.   0.
#     1.  29.   2.   1.   1.]
#  [ 31.   0.  31.   7.   3.   0.   0.   0.   0.   2.   0.   0.   0.   0.
#     1.  25.   3.   1.   1.]
#  [ 88.  21.  10.   9.   2.   1.   0.   1.   0.   3.   4.   1.   0.   1.
#     7.  63.   1.   1.   1.]
#  [235.  23.  10.   9.   3.   1.   0.   1.   0.   2.   3.   1.   0.   0.
#    22. 199.   1.   1.   1.]]
# Urls:  ['br-icloud.com.br', 'mp3raid.com/music/krizz_kaliko.html', 'bopsecrets.org/rexroth/cr/1.htm', 'http://www.garage-pirenne.be/index.php?option=com_content&view=article&id=70&vsig70_0=15', 'http://adventure-nicaragua.net/index.php?option=com_mailto&tmpl=component&link=aHR0cDovL2FkdmVudHVyZS1uaWNhcmFndWEubmV0L2luZGV4LnBocD9vcHRpb249Y29tX2NvbnRlbnQmdmlldz1hcnRpY2xlJmlkPTQ3OmFib3V0JmNhdGlkPTM2OmRlbW8tYXJ0aWNsZXMmSXRlbWlkPTU0']

# %% [markdown]
# # Dataset Split
#
# Split dataset into Train, Test and Validation
# Percentages of split: 70%, 15%, 15%

# %%
# First, split the data into training and a combined test/validation set (temporary dataset)
x_train, x_temp, y_train, y_temp, url_train, url_temp = train_test_split(
    x, y, urls, test_size=0.3)

# Then, split the temporary set into separate test and validation sets
x_test, x_val, y_test, y_val, url_test, url_val = train_test_split(
    x_temp, y_temp, url_temp, test_size=0.5)

# Print the shapes to verify the splits
print("Training set:", x_train.shape, y_train.shape, len(url_train))
print("Test set:", x_test.shape, y_test.shape, len(url_test))
print("Validation set:", x_val.shape, y_val.shape, len(url_val))
# Out:
# Training set: (455833, 19) (455833,) 455833
# Test set: (97679, 19) (97679,) 97679
# Validation set: (97679, 19) (97679,) 97679

# %% [markdown]
# # Training of the NN

# %%
# Convert the labels to categorical
y_train = to_categorical(y_train, num_classes=4)
y_val = to_categorical(y_val, num_classes=4)
y_test = to_categorical(y_test, num_classes=4)

# Define the neural network model
# model = Sequential([
#     Dense(64, input_shape=(x_train.shape[1],), activation='relu'),
#     Dropout(0.5),
#     Dense(64, activation='relu'),
#     Dropout(0.5),
#     Dense(32, activation='relu'),
#     Dropout(0.5),
#     Dense(4, activation='softmax')
# ])

# Incresed layer model
# model = Sequential([
#     Dense(128, input_shape=(x_train.shape[1],), activation='relu'),
#     BatchNormalization(),
#     Dropout(0.5),
#     Dense(128, activation='relu'),
#     BatchNormalization(),
#     Dropout(0.5),
#     Dense(64, activation='relu'),
#     BatchNormalization(),
#     Dropout(0.5),
#     Dense(32, activation='relu'),
#     BatchNormalization(),
#     Dropout(0.5),
#     Dense(4, activation='softmax')
# ])

# Final model
model = Sequential([
    Dense(256, input_shape=(x_train.shape[1],), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(4, activation='softmax')
])

optimizer = Adam(learning_rate=0.001)

# Compile the model
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

# Train the model
history = model.fit(x_train, y_train, epochs=100, batch_size=64, validation_data=(x_val, y_val), callbacks=[early_stopping, reduce_lr])

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_accuracy}')

model.summary()
# Out:
# Epoch 1/100
# 7123/7123 [==============================] - 48s 6ms/step - loss: 0.5867 - accuracy: 0.8489 - val_loss: 0.3767 - val_accuracy: 0.8923 - lr: 0.0010
# Epoch 2/100
# 7123/7123 [==============================] - 51s 7ms/step - loss: 0.4199 - accuracy: 0.8793 - val_loss: 0.3495 - val_accuracy: 0.9031 - lr: 0.0010
# Epoch 3/100
# 7123/7123 [==============================] - 45s 6ms/step - loss: 0.4162 - accuracy: 0.8808 - val_loss: 0.3458 - val_accuracy: 0.9057 - lr: 0.0010
# Epoch 4/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.4081 - accuracy: 0.8834 - val_loss: 0.3197 - val_accuracy: 0.9119 - lr: 0.0010
# Epoch 5/100
# 7123/7123 [==============================] - 47s 7ms/step - loss: 0.4118 - accuracy: 0.8809 - val_loss: 0.3151 - val_accuracy: 0.9117 - lr: 0.0010
# Epoch 6/100
# 7123/7123 [==============================] - 45s 6ms/step - loss: 0.4068 - accuracy: 0.8828 - val_loss: 0.3588 - val_accuracy: 0.9035 - lr: 0.0010
# Epoch 7/100
# 7123/7123 [==============================] - 45s 6ms/step - loss: 0.4063 - accuracy: 0.8830 - val_loss: 0.3204 - val_accuracy: 0.9115 - lr: 0.0010
# Epoch 8/100
# 7123/7123 [==============================] - 47s 7ms/step - loss: 0.3993 - accuracy: 0.8851 - val_loss: 0.3277 - val_accuracy: 0.9089 - lr: 0.0010
# Epoch 9/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.4030 - accuracy: 0.8834 - val_loss: 0.3356 - val_accuracy: 0.9039 - lr: 0.0010
# Epoch 10/100
# 7123/7123 [==============================] - 46s 7ms/step - loss: 0.3976 - accuracy: 0.8853 - val_loss: 0.3154 - val_accuracy: 0.9133 - lr: 0.0010
# Epoch 11/100
# 7123/7123 [==============================] - 45s 6ms/step - loss: 0.3451 - accuracy: 0.8988 - val_loss: 0.2651 - val_accuracy: 0.9191 - lr: 2.0000e-04
# Epoch 12/100
# 7123/7123 [==============================] - 48s 7ms/step - loss: 0.3227 - accuracy: 0.9020 - val_loss: 0.2535 - val_accuracy: 0.9202 - lr: 2.0000e-04
# Epoch 13/100
# 7123/7123 [==============================] - 50s 7ms/step - loss: 0.3120 - accuracy: 0.9043 - val_loss: 0.2491 - val_accuracy: 0.9211 - lr: 2.0000e-04
# Epoch 14/100
# 7123/7123 [==============================] - 48s 7ms/step - loss: 0.3079 - accuracy: 0.9048 - val_loss: 0.2462 - val_accuracy: 0.9229 - lr: 2.0000e-04
# Epoch 15/100
# 7123/7123 [==============================] - 45s 6ms/step - loss: 0.3033 - accuracy: 0.9065 - val_loss: 0.2458 - val_accuracy: 0.9227 - lr: 2.0000e-04
# Epoch 16/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.3021 - accuracy: 0.9063 - val_loss: 0.2421 - val_accuracy: 0.9231 - lr: 2.0000e-04
# Epoch 17/100
# 7123/7123 [==============================] - 48s 7ms/step - loss: 0.3004 - accuracy: 0.9071 - val_loss: 0.2427 - val_accuracy: 0.9208 - lr: 2.0000e-04
# Epoch 18/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.2981 - accuracy: 0.9082 - val_loss: 0.2451 - val_accuracy: 0.9215 - lr: 2.0000e-04
# Epoch 19/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.2976 - accuracy: 0.9083 - val_loss: 0.2416 - val_accuracy: 0.9224 - lr: 2.0000e-04
# Epoch 20/100
# 7123/7123 [==============================] - 47s 7ms/step - loss: 0.2946 - accuracy: 0.9091 - val_loss: 0.2395 - val_accuracy: 0.9225 - lr: 2.0000e-04
# Epoch 21/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.2947 - accuracy: 0.9088 - val_loss: 0.2556 - val_accuracy: 0.9181 - lr: 2.0000e-04
# Epoch 22/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.2940 - accuracy: 0.9094 - val_loss: 0.2351 - val_accuracy: 0.9242 - lr: 2.0000e-04
# Epoch 23/100
# 7123/7123 [==============================] - 47s 7ms/step - loss: 0.2940 - accuracy: 0.9094 - val_loss: 0.2389 - val_accuracy: 0.9240 - lr: 2.0000e-04
# Epoch 24/100
# 7123/7123 [==============================] - 46s 6ms/step - loss: 0.2929 - accuracy: 0.9097 - val_loss: 0.2366 - val_accuracy: 0.9258 - lr: 2.0000e-04
# Epoch 25/100
# 7123/7123 [==============================] - 47s 7ms/step - loss: 0.2925 - accuracy: 0.9103 - val_loss: 0.2371 - val_accuracy: 0.9256 - lr: 2.0000e-04
# Epoch 26/100
# 7123/7123 [==============================] - 45s 6ms/step - loss: 0.2923 - accuracy: 0.9103 - val_loss: 0.2417 - val_accuracy: 0.9230 - lr: 2.0000e-04
# Epoch 27/100
# 7123/7123 [==============================] - 48s 7ms/step - loss: 0.2915 - accuracy: 0.9103 - val_loss: 0.2374 - val_accuracy: 0.9249 - lr: 2.0000e-04
# Epoch 28/100
# 7123/7123 [==============================] - 46s 6ms/step - loss: 0.2757 - accuracy: 0.9153 - val_loss: 0.2217 - val_accuracy: 0.9329 - lr: 4.0000e-05
# Epoch 29/100
# 7123/7123 [==============================] - 48s 7ms/step - loss: 0.2692 - accuracy: 0.9175 - val_loss: 0.2146 - val_accuracy: 0.9358 - lr: 4.0000e-05
# Epoch 30/100
# 7123/7123 [==============================] - 46s 6ms/step - loss: 0.2648 - accuracy: 0.9184 - val_loss: 0.2183 - val_accuracy: 0.9334 - lr: 4.0000e-05
# Epoch 31/100
# 7123/7123 [==============================] - 46s 6ms/step - loss: 0.2632 - accuracy: 0.9187 - val_loss: 0.2122 - val_accuracy: 0.9347 - lr: 4.0000e-05
# Epoch 32/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.2606 - accuracy: 0.9193 - val_loss: 0.2098 - val_accuracy: 0.9360 - lr: 4.0000e-05
# Epoch 33/100
# 7123/7123 [==============================] - 46s 6ms/step - loss: 0.2584 - accuracy: 0.9200 - val_loss: 0.2091 - val_accuracy: 0.9355 - lr: 4.0000e-05
# Epoch 34/100
# 7123/7123 [==============================] - 47s 7ms/step - loss: 0.2575 - accuracy: 0.9197 - val_loss: 0.2069 - val_accuracy: 0.9366 - lr: 4.0000e-05
# Epoch 35/100
# 7123/7123 [==============================] - 46s 6ms/step - loss: 0.2572 - accuracy: 0.9200 - val_loss: 0.2041 - val_accuracy: 0.9370 - lr: 4.0000e-05
# Epoch 36/100
# 7123/7123 [==============================] - 48s 7ms/step - loss: 0.2564 - accuracy: 0.9204 - val_loss: 0.2053 - val_accuracy: 0.9367 - lr: 4.0000e-05
# Epoch 37/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.2548 - accuracy: 0.9206 - val_loss: 0.2024 - val_accuracy: 0.9380 - lr: 4.0000e-05
# Epoch 38/100
# 7123/7123 [==============================] - 46s 7ms/step - loss: 0.2538 - accuracy: 0.9211 - val_loss: 0.2038 - val_accuracy: 0.9378 - lr: 4.0000e-05
# Epoch 39/100
# 7123/7123 [==============================] - 48s 7ms/step - loss: 0.2533 - accuracy: 0.9212 - val_loss: 0.2026 - val_accuracy: 0.9394 - lr: 4.0000e-05
# Epoch 40/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.2523 - accuracy: 0.9213 - val_loss: 0.2030 - val_accuracy: 0.9370 - lr: 4.0000e-05
# Epoch 41/100
# 7123/7123 [==============================] - 45s 6ms/step - loss: 0.2518 - accuracy: 0.9217 - val_loss: 0.2002 - val_accuracy: 0.9396 - lr: 4.0000e-05
# Epoch 42/100
# 7123/7123 [==============================] - 46s 6ms/step - loss: 0.2513 - accuracy: 0.9217 - val_loss: 0.2020 - val_accuracy: 0.9383 - lr: 4.0000e-05
# Epoch 43/100
# 7123/7123 [==============================] - 44s 6ms/step - loss: 0.2509 - accuracy: 0.9215 - val_loss: 0.1992 - val_accuracy: 0.9389 - lr: 4.0000e-05
# Epoch 44/100
# 7123/7123 [==============================] - 44s 6ms/step - loss: 0.2505 - accuracy: 0.9217 - val_loss: 0.2022 - val_accuracy: 0.9370 - lr: 4.0000e-05
# Epoch 45/100
# 7123/7123 [==============================] - 44s 6ms/step - loss: 0.2487 - accuracy: 0.9222 - val_loss: 0.2022 - val_accuracy: 0.9374 - lr: 4.0000e-05
# Epoch 46/100
# 7123/7123 [==============================] - 44s 6ms/step - loss: 0.2498 - accuracy: 0.9224 - val_loss: 0.2014 - val_accuracy: 0.9389 - lr: 4.0000e-05
# Epoch 47/100
# 7123/7123 [==============================] - 44s 6ms/step - loss: 0.2487 - accuracy: 0.9223 - val_loss: 0.1982 - val_accuracy: 0.9377 - lr: 4.0000e-05
# Epoch 48/100
# 7123/7123 [==============================] - 47s 7ms/step - loss: 0.2479 - accuracy: 0.9225 - val_loss: 0.1983 - val_accuracy: 0.9389 - lr: 4.0000e-05
# Epoch 49/100
# 7123/7123 [==============================] - 47s 7ms/step - loss: 0.2482 - accuracy: 0.9224 - val_loss: 0.1960 - val_accuracy: 0.9399 - lr: 4.0000e-05
# Epoch 50/100
# 7123/7123 [==============================] - 46s 6ms/step - loss: 0.2482 - accuracy: 0.9223 - val_loss: 0.1977 - val_accuracy: 0.9385 - lr: 4.0000e-05
# Epoch 51/100
# 7123/7123 [==============================] - 47s 7ms/step - loss: 0.2468 - accuracy: 0.9226 - val_loss: 0.1963 - val_accuracy: 0.9390 - lr: 4.0000e-05
# Epoch 52/100
# 7123/7123 [==============================] - 46s 6ms/step - loss: 0.2474 - accuracy: 0.9223 - val_loss: 0.1961 - val_accuracy: 0.9396 - lr: 4.0000e-05
# Epoch 53/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.2461 - accuracy: 0.9227 - val_loss: 0.1963 - val_accuracy: 0.9394 - lr: 4.0000e-05
# Epoch 54/100
# 7123/7123 [==============================] - 51s 7ms/step - loss: 0.2463 - accuracy: 0.9229 - val_loss: 0.1964 - val_accuracy: 0.9400 - lr: 4.0000e-05
# Epoch 55/100
# 7123/7123 [==============================] - 48s 7ms/step - loss: 0.2425 - accuracy: 0.9246 - val_loss: 0.1925 - val_accuracy: 0.9412 - lr: 1.0000e-05
# Epoch 56/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.2407 - accuracy: 0.9248 - val_loss: 0.1913 - val_accuracy: 0.9412 - lr: 1.0000e-05
# Epoch 57/100
# 7123/7123 [==============================] - 46s 6ms/step - loss: 0.2400 - accuracy: 0.9253 - val_loss: 0.1906 - val_accuracy: 0.9409 - lr: 1.0000e-05
# Epoch 58/100
# 7123/7123 [==============================] - 48s 7ms/step - loss: 0.2400 - accuracy: 0.9251 - val_loss: 0.1905 - val_accuracy: 0.9412 - lr: 1.0000e-05
# Epoch 59/100
# 7123/7123 [==============================] - 46s 7ms/step - loss: 0.2388 - accuracy: 0.9255 - val_loss: 0.1898 - val_accuracy: 0.9418 - lr: 1.0000e-05
# Epoch 60/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.2383 - accuracy: 0.9255 - val_loss: 0.1892 - val_accuracy: 0.9419 - lr: 1.0000e-05
# Epoch 61/100
# 7123/7123 [==============================] - 46s 7ms/step - loss: 0.2385 - accuracy: 0.9254 - val_loss: 0.1892 - val_accuracy: 0.9416 - lr: 1.0000e-05
# Epoch 62/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.2387 - accuracy: 0.9253 - val_loss: 0.1894 - val_accuracy: 0.9408 - lr: 1.0000e-05
# Epoch 63/100
# 7123/7123 [==============================] - 52s 7ms/step - loss: 0.2381 - accuracy: 0.9256 - val_loss: 0.1900 - val_accuracy: 0.9419 - lr: 1.0000e-05
# Epoch 64/100
# 7123/7123 [==============================] - 48s 7ms/step - loss: 0.2374 - accuracy: 0.9259 - val_loss: 0.1885 - val_accuracy: 0.9419 - lr: 1.0000e-05
# Epoch 65/100
# 7123/7123 [==============================] - 48s 7ms/step - loss: 0.2375 - accuracy: 0.9255 - val_loss: 0.1890 - val_accuracy: 0.9414 - lr: 1.0000e-05
# Epoch 66/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.2370 - accuracy: 0.9258 - val_loss: 0.1888 - val_accuracy: 0.9418 - lr: 1.0000e-05
# Epoch 67/100
# 7123/7123 [==============================] - 50s 7ms/step - loss: 0.2370 - accuracy: 0.9260 - val_loss: 0.1875 - val_accuracy: 0.9418 - lr: 1.0000e-05
# Epoch 68/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.2370 - accuracy: 0.9258 - val_loss: 0.1872 - val_accuracy: 0.9418 - lr: 1.0000e-05
# Epoch 69/100
# 7123/7123 [==============================] - 46s 7ms/step - loss: 0.2364 - accuracy: 0.9260 - val_loss: 0.1874 - val_accuracy: 0.9418 - lr: 1.0000e-05
# Epoch 70/100
# 7123/7123 [==============================] - 52s 7ms/step - loss: 0.2364 - accuracy: 0.9265 - val_loss: 0.1876 - val_accuracy: 0.9420 - lr: 1.0000e-05
# Epoch 71/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.2366 - accuracy: 0.9259 - val_loss: 0.1871 - val_accuracy: 0.9421 - lr: 1.0000e-05
# Epoch 72/100
# 7123/7123 [==============================] - 47s 7ms/step - loss: 0.2367 - accuracy: 0.9260 - val_loss: 0.1869 - val_accuracy: 0.9425 - lr: 1.0000e-05
# Epoch 73/100
# 7123/7123 [==============================] - 46s 6ms/step - loss: 0.2351 - accuracy: 0.9263 - val_loss: 0.1877 - val_accuracy: 0.9415 - lr: 1.0000e-05
# Epoch 74/100
# 7123/7123 [==============================] - 47s 7ms/step - loss: 0.2356 - accuracy: 0.9262 - val_loss: 0.1871 - val_accuracy: 0.9421 - lr: 1.0000e-05
# Epoch 75/100
# 7123/7123 [==============================] - 46s 6ms/step - loss: 0.2346 - accuracy: 0.9262 - val_loss: 0.1866 - val_accuracy: 0.9426 - lr: 1.0000e-05
# Epoch 76/100
# 7123/7123 [==============================] - 48s 7ms/step - loss: 0.2351 - accuracy: 0.9265 - val_loss: 0.1870 - val_accuracy: 0.9419 - lr: 1.0000e-05
# Epoch 77/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.2350 - accuracy: 0.9262 - val_loss: 0.1859 - val_accuracy: 0.9426 - lr: 1.0000e-05
# Epoch 78/100
# 7123/7123 [==============================] - 48s 7ms/step - loss: 0.2348 - accuracy: 0.9263 - val_loss: 0.1856 - val_accuracy: 0.9425 - lr: 1.0000e-05
# Epoch 79/100
# 7123/7123 [==============================] - 46s 7ms/step - loss: 0.2337 - accuracy: 0.9270 - val_loss: 0.1864 - val_accuracy: 0.9427 - lr: 1.0000e-05
# Epoch 80/100
# 7123/7123 [==============================] - 48s 7ms/step - loss: 0.2340 - accuracy: 0.9264 - val_loss: 0.1860 - val_accuracy: 0.9423 - lr: 1.0000e-05
# Epoch 81/100
# 7123/7123 [==============================] - 47s 7ms/step - loss: 0.2346 - accuracy: 0.9263 - val_loss: 0.1857 - val_accuracy: 0.9423 - lr: 1.0000e-05
# Epoch 82/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.2339 - accuracy: 0.9267 - val_loss: 0.1852 - val_accuracy: 0.9429 - lr: 1.0000e-05
# Epoch 83/100
# 7123/7123 [==============================] - 47s 7ms/step - loss: 0.2335 - accuracy: 0.9268 - val_loss: 0.1847 - val_accuracy: 0.9422 - lr: 1.0000e-05
# Epoch 84/100
# 7123/7123 [==============================] - 50s 7ms/step - loss: 0.2340 - accuracy: 0.9267 - val_loss: 0.1860 - val_accuracy: 0.9422 - lr: 1.0000e-05
# Epoch 85/100
# 7123/7123 [==============================] - 46s 7ms/step - loss: 0.2345 - accuracy: 0.9261 - val_loss: 0.1850 - val_accuracy: 0.9420 - lr: 1.0000e-05
# Epoch 86/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.2342 - accuracy: 0.9265 - val_loss: 0.1852 - val_accuracy: 0.9424 - lr: 1.0000e-05
# Epoch 87/100
# 7123/7123 [==============================] - 46s 7ms/step - loss: 0.2336 - accuracy: 0.9267 - val_loss: 0.1854 - val_accuracy: 0.9424 - lr: 1.0000e-05
# Epoch 88/100
# 7123/7123 [==============================] - 48s 7ms/step - loss: 0.2332 - accuracy: 0.9267 - val_loss: 0.1843 - val_accuracy: 0.9427 - lr: 1.0000e-05
# Epoch 89/100
# 7123/7123 [==============================] - 46s 7ms/step - loss: 0.2327 - accuracy: 0.9272 - val_loss: 0.1855 - val_accuracy: 0.9424 - lr: 1.0000e-05
# Epoch 90/100
# 7123/7123 [==============================] - 48s 7ms/step - loss: 0.2335 - accuracy: 0.9268 - val_loss: 0.1848 - val_accuracy: 0.9421 - lr: 1.0000e-05
# Epoch 91/100
# 7123/7123 [==============================] - 46s 6ms/step - loss: 0.2329 - accuracy: 0.9270 - val_loss: 0.1839 - val_accuracy: 0.9427 - lr: 1.0000e-05
# Epoch 92/100
# 7123/7123 [==============================] - 48s 7ms/step - loss: 0.2332 - accuracy: 0.9267 - val_loss: 0.1846 - val_accuracy: 0.9427 - lr: 1.0000e-05
# Epoch 93/100
# 7123/7123 [==============================] - 46s 7ms/step - loss: 0.2328 - accuracy: 0.9268 - val_loss: 0.1843 - val_accuracy: 0.9430 - lr: 1.0000e-05
# Epoch 94/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.2321 - accuracy: 0.9271 - val_loss: 0.1841 - val_accuracy: 0.9426 - lr: 1.0000e-05
# Epoch 95/100
# 7123/7123 [==============================] - 52s 7ms/step - loss: 0.2334 - accuracy: 0.9267 - val_loss: 0.1833 - val_accuracy: 0.9436 - lr: 1.0000e-05
# Epoch 96/100
# 7123/7123 [==============================] - 49s 7ms/step - loss: 0.2323 - accuracy: 0.9271 - val_loss: 0.1834 - val_accuracy: 0.9430 - lr: 1.0000e-05
# Epoch 97/100
# 7123/7123 [==============================] - 50s 7ms/step - loss: 0.2317 - accuracy: 0.9272 - val_loss: 0.1834 - val_accuracy: 0.9431 - lr: 1.0000e-05
# Epoch 98/100
# 7123/7123 [==============================] - 50s 7ms/step - loss: 0.2328 - accuracy: 0.9273 - val_loss: 0.1827 - val_accuracy: 0.9433 - lr: 1.0000e-05
# Epoch 99/100
# 7123/7123 [==============================] - 51s 7ms/step - loss: 0.2315 - accuracy: 0.9275 - val_loss: 0.1831 - val_accuracy: 0.9431 - lr: 1.0000e-05
# Epoch 100/100
# 7123/7123 [==============================] - 51s 7ms/step - loss: 0.2316 - accuracy: 0.9272 - val_loss: 0.1838 - val_accuracy: 0.9425 - lr: 1.0000e-05
# 3053/3053 [==============================] - 7s 2ms/step - loss: 0.1882 - accuracy: 0.9428
# Test accuracy: 0.9427614808082581
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               5120
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  batch_normalization_1 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  batch_normalization_2 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  batch_normalization_3 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 65348 (255.27 KB)
# Trainable params: 64196 (250.77 KB)
# Non-trainable params: 1152 (4.50 KB)
# _________________________________________________________________

# %%
# Generate classification report
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)
print(classification_report(y_true, y_pred_classes, target_names=class_dictionary.keys()))

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()

# Plot confusion matrix as a heatmap
conf_matrix = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_dictionary.keys(), yticklabels=class_dictionary.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 3053/3053 [==============================] - 7s 2ms/step
