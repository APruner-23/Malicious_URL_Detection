# %% [markdown]
# <a href="https://colab.research.google.com/github/APruner-23/Malicious_URL_Detection/blob/main/Feature_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Here only code about feature extraction**

# %%
# !pip install tld
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.8/263.8 kB 1.6 MB/s eta 0:00:00
# ...

# %%
## imports

import pandas as pd
from urllib.parse import urlparse
from tld import get_tld
import os.path
import re
import requests

# %%
## extracting data

# URL to the  dataset in the GitHub repository
link = 'https://raw.githubusercontent.com/APruner-23/Malicious_URL_Detection/main/malicious_phish1.csv'
#extraction
urldata = pd.read_csv(link)

# %%
## preprocessing data - tld

#function which return the tld
def get_all_tld(url):
    url_tld = []
    for i in range(len(url)) :
      tld = get_tld(url[i],fail_silently=True)
      if tld not in url_tld :
        url_tld.append(tld)
    return(url_tld)

url_tld = get_all_tld(urldata['url'])

print(url_tld)

## expected output and the list that we are gonna use
#[None, 'be', 'net', 'com', 'nl', 'de', 'hu', 'co', 'it', 'ac.uk', 'com.br', 'ir', 'org', 'pl', 'gr', 'ru', 'com.ua', 'info', 'vn', 'ro', 'cl', 'com.ar', 'ca', 'sk', 'es', 'co.uk', 'si', 'biz', 'net.br', 'ind.br', 'kiev.ua', 'net.vn', 'cc', 'at', 'tv', 'eu', 'cn', 'com.vn', 'com.my', 'cz', 'com.au', 'jp', 'dk', 'fr', 'co.za', 'lt', 'md', 'fi', 'blogspot.com', 'co.id', 'edu.co', 'com.tr', 'in', 'org.au', 'se', 'ch', 'com.pl', 'ee', 'com.sg', 'us', 'bn.it', 'com.cn', 'gov.br', 'ph', 'mx', 'co.kr', 'net.ua', 'k12.tr', 'gov.uk', 'com.gr', 'asia', 'co.th', 'ua', 'info.pl', 'com.mx', 'no', 'pt', 'co.zw', 'ie', 'co.nz', 'kz', 'org.uk', 'nu', 'eu.com', 'is', 'nhs.uk', 'lu', 'edu.pe', 'rs', 'com.cy', 'uz', 'org.cn', 'org.za', 'pe', 'pk', 'in.ua', 'gov.gr', 'org.br', 'is-a-libertarian.com', 'com.co', 'com.ba', 'com.bo', 'cv', 'ab.ca', 'travel.pl', 'com.pe', 'altervista.org', 'io', 'to', 'az', 'com.tw', 'blogspot.co.uk', 'org.tr', 'im', 'ge', 'co.jp', 'su', 'edu.au', 'co.il', 'co.rs', 'com.hk', 'ac.th', 'net.au', 'ac.cr', 'go.id', 'googleapis.com', 'tk', 'net.my', 'name', 'pythonanywhere.com', 'me', 'blogspot.com.br', 's3.amazonaws.com', 'gov.tr', 'or.id', 'net.pl', 'net.cn', 'org.co', 'com.ph', 'me.uk', 'sh.cn', 'by', 'co.in', 'mn', 'gov', 'ac.id', 'us-east-1.elb.amazonaws.com', 'com.bt', 'com.ec', 'edu.cn', 'com.ve', 'ly', 'edu.br', 'mobi', 'web.id', 'com.py', 'is-a-financialadvisor.com', 'gov.cn', 'bg', 'lv', 'in.rs', 'edu.my', 'k12.wi.us', 'asn.au', 'guru', 'org.nz', 'yolasite.com', 'vn.ua', 'co.tz', 'com.pk', 'kr', 'tj', 'so', 'gen.tr', 'ac', 'vu', 'la', 'vic.edu.au', 'go.th', 'kinghost.net', 'myqnapcloud.com', 'edu', 'gob.mx', 'edu.pk', 'kutno.pl', 'space', 'ne.jp', 'blogspot.ca', 'msk.ru', 'net.ma', 'dyndns-web.com', 'ac.ke', 'gob.pe', 'com.sa', 'org.mk', 'org.ar', 'boldlygoingnowhere.org', 'co.ua', 'xyz', 'jelastic.dogado.eu', 'ga', 'cat', 'sg', 'cool', 'blogspot.com.au', 'gm', 'co.ke', 'gs', 'ps', 'cf', 'pro', 'sx', 'com.eg', 'hm', 'myjino.ru', 'art.br', 'hr', 'biz.tr', 'od.ua', 'af', 'pn', 'co.ma', 'net.mx', 'cx', 'xn--p1ai', 'ws', 'nf', 's3-eu-west-1.amazonaws.com', 'help', 'com.ng', 'tf', 'tn', 'edu.kh', 'ad', 'adm.br', 'googlecode.com', 'host', 'com.do', 'blogspot.in', 'org.ru', 'edu.rs', 'university', 'ma', 'my', 'org.in', 'bs.it', 'blogspot.nl', 'com.pt', 'zj.cn', 'ac.in', 'org.ph', 'or.kr', 'or.tz', 'id.au', 'ae', 'org.zm', 'gov.np', 'lowicz.pl', 'edu.ec', 'sa', 'gov.sa', 'nr', 'in.th', 'me.ke', 'com.np', 'edu.mx', 'org.rs', 'name.my', 'poznan.pl', 'hk', 'li', 'party', 'no-ip.info', 'org.py', 'thruhere.net', 'lk', 'net.in', 'adv.br', 'no-ip.org', 'club', 's3-website-us-east-1.amazonaws.com', 'inf.br', 'mk', 'rw', 'vg', 'appspot.com', 'com.uy', 'net.tw', 'lutsk.ua', 'ftpaccess.cc', 'top', 'group', 'site', 'nyc', 'duckdns.org', 'casacam.net', 'icu', 'one', 'ba', 'ml', 'wn.r.appspot.com', 'uc.r.appspot.com', 'buzz', 'work', 'my.id', 'gr.jp', 'online', 'com.ru', 'bar', 'desa.id', 'fun', 'ddnslive.com', 'ddnsfree.com', 'gb.net', 'dnsup.net', '64-b.it', 'tcp4.me', 'id', 'gq', 'glitch.me', 'gd', 'cloudaccess.host', 'app', 'store', 'ue.r.appspot.com', 'business', 'services', 'ms', 'ru.com', 'gotdns.ch', 'email', 'monster', 'sa-east-1.elasticbeanstalk.com', 'dynv6.net', 'cloud-fr1.unispace.io', 'webredirect.org', 'navy', 'army', 'med.br', 'tw', 'ooguy.com', 'gov.ar', 'domains', 'blog', 'rj.r.appspot.com', 'shop', 'bounceme.net', 'ddnsgeek.com', 'link', 'com.hr', 'accesscam.org', 'ddns.net', 'cluster028.hosting.ovh.net', 'live', 'gt', 'page', 'press', 'nz', 'ltd', 'net.za', 'sh', 'for-more.biz', 'jdevcloud.com', 'go.tz', 'fo', 'org.pk', 'sytes.net', 'web.app', 'sn', 'el.r.appspot.com', 'is-a-designer.com', 'website', 'serveirc.com', 'digital', 'bz', 'nn.r.appspot.com', 'cloud', 'do', 'uk', 'mywire.org', 'br', 'ovh', 'tech', 'netlify.app', 'gl', 'firebaseapp.com', 'azurewebsites.net', 'company', 'am', 'uk.com', 'video', 'df.r.appspot.com', 'is-slick.com', 'tv.br', 'team', 'ng', 'krakow.pl', 'oa.r.appspot.com', 'wixsite.com', 'com.sv', 'edu.hk', 'gle', 'com.bd', 'studio', 's3.ap-northeast-2.amazonaws.com', 'is-a-hard-worker.com', 'pp.ua', 'mcdir.ru', 'rest', 'redirectme.net', 'events', 'life', 'blogspot.rs', 'loan', 'edu.vn', 'casa', 'ai', 'rocks', 'bt', 'net.ar', 'org.ua', 'gdn', 'gov.la', 'art', 'today', 'gob.sv', 'mcpre.ru', 'vip', 'technology', 'wpdevcloud.com', 'best', 'click', 'tools', 'sm', 'org.pl', 'za.net', 'cm', 'com.gh', 'qa', 'pm', 'edu.ng', 'world', 'center', 'repl.co', 'cam', 'org.np', 'herokuapp.com', 'mp', 'com.gt', 'edu.ar', 'pp.ru', 'edu.af', 'srv.br', 'support', 'solutions', 'sch.id', 'house', 'b.br', 'bid', 'blog.br', 'mypi.co', 'ec2-3-82-210-25.compute-1.amazonaws.com', 'cloudfront.net', 'edu.np', 'synology.me', 'blogspot.be', 'edu.ua', 'mk.ua', 'dp.ua', 'itau', 'pw', 'london', 'fm', 'blogspot.gr', 'radio.br', 're', 'org.mx', 'k12.mo.us', 's3-ap-southeast-1.amazonaws.com', 'kalisz.pl', 'uni5.net', 'pr', 'kim', 'gg', 'fg.it', 'org.gr', 'cash', 'repl.run', 'com.kz', 'akadns.net', 'biz.ua', 'go.ug', 'ci', 'gitlab.io', 'al', 'uy', 'edu.ph', 'cheap', 'dreamhosters.com', 'net.ng', 'spb.ru', 'edu.tr', 'ag', 'cloud.goog', 'cloudns.asia', 'github.io', 'expert', 'lviv.ua', 'as', 'net.nz', 'wf', 'sfo2.digitaloceanspaces.com', 'ec', 'blogspot.ru', 'co.ao', 'tl', 'blogspot.it', 'bf', 'stargard.pl', 'mu', 'biz.pl', 'ug', 'gov.kg', 'ngrok.io', 'jellybean.jp', 'ams3.digitaloceanspaces.com', 'chowder.jp', 'download', 'ninja', 'red', 'hopto.org', 's3-us-west-1.amazonaws.com', 'gratis', 'win', 'ilawa.pl', 'org.my', 'whitesnow.jp', 'chillout.jp', 'lovesick.jp', 'namaste.jp', 'fem.jp', 'cluster020.hosting.ovh.net', 'com.de', 'myftp.biz', 'gov.pk', 'llc', 'eurodir.ru', 'org.hk', 'ht']


# checking the reputation of the tld : 0 means that it's safe and 5 means that it's dangerous

tld_dangerosity = {
    'None': 3,
    'be': 2,
    'net': 3,
    'com': 3,
    'nl': 2,
    'de': 2,
    'hu': 2,
    'co': 3,
    'it': 2,
    'ac.uk': 1,
    'com.br': 2,
    'ir': 4,
    'org': 2,
    'pl': 2,
    'gr': 2,
    'ru': 5,
    'com.ua': 4,
    'info': 3,
    'vn': 3,
    'ro': 2,
    'cl': 2,
    'com.ar': 2,
    'ca': 1,
    'sk': 2,
    'es': 2,
    'co.uk': 1,
    'si': 2,
    'biz': 3,
    'net.br': 2,
    'ind.br': 1,
    'kiev.ua': 4,
    'net.vn': 3,
    'cc': 3,
    'at': 2,
    'tv': 3,
    'eu': 2,
    'cn': 5,
    'com.vn': 3,
    'com.my': 3,
    'cz': 2,
    'com.au': 1,
    'jp': 1,
    'dk': 1,
    'fr': 1,
    'co.za': 3,
    'lt': 2,
    'md': 3,
    'fi': 1,
    'blogspot.com': 3,
    'co.id': 3,
    'edu.co': 1,
    'com.tr': 2,
    'in': 3,
    'org.au': 1,
    'se': 1,
    'ch': 1,
    'com.pl': 2,
    'ee': 2,
    'com.sg': 2,
    'us': 1,
    'bn.it': 1,
    'com.cn': 5,
    'gov.br': 0,
    'ph': 3,
    'mx': 3,
    'co.kr': 1,
    'net.ua': 4,
    'k12.tr': 1,
    'gov.uk': 0,
    'com.gr': 3,
    'asia': 3,
    'co.th': 3,
    'ua': 4,
    'info.pl': 2,
    'com.mx': 3,
    'no': 1,
    'pt': 2,
    'co.zw': 3,
    'ie': 1,
    'co.nz': 1,
    'kz': 3,
    'org.uk': 1,
    'nu': 3,
    'eu.com': 3,
    'is': 1,
    'nhs.uk': 0,
    'lu': 1,
    'edu.pe': 1,
    'rs': 2,
    'com.cy': 3,
    'uz': 3,
    'org.cn': 5,
    'org.za': 3,
    'pe': 3,
    'pk': 4,
    'in.ua': 4,
    'gov.gr': 0,
    'org.br': 2,
    'is-a-libertarian.com': 3,
    'com.co': 3,
    'com.ba': 3,
    'com.bo': 3,
    'cv': 2,
    'ab.ca': 1,
    'travel.pl': 2,
    'com.pe': 3,
    'altervista.org': 3,
    'io': 2,
    'to': 3,
    'az': 3,
    'com.tw': 3,
    'blogspot.co.uk': 3,
    'org.tr': 2,
    'im': 2,
    'ge': 3,
    'co.jp': 1,
    'su': 4,
    'edu.au': 1,
    'co.il': 1,
    'co.rs': 3,
    'com.hk': 3,
    'ac.th': 1,
    'net.au': 1,
    'ac.cr': 1,
    'go.id': 1,
    'googleapis.com': 2,
    'tk': 4,
    'net.my': 3,
    'name': 3,
    'pythonanywhere.com': 2,
    'me': 3,
    'blogspot.com.br': 3,
    's3.amazonaws.com': 2,
    'gov.tr': 0,
    'or.id': 3,
    'net.pl': 2,
    'net.cn': 5,
    'org.co': 3,
    'com.ph': 3,
    'me.uk': 2,
    'sh.cn': 5,
    'by': 4,
    'co.in': 3,
    'mn': 3,
    'gov': 0,
    'ac.id': 1,
    'us-east-1.elb.amazonaws.com': 2,
    'com.bt': 2,
    'com.ec': 3,
    'edu.cn': 5,
    'com.ve': 3,
    'ly': 4,
    'edu.br': 1,
    'mobi': 3,
    'web.id': 3,
    'com.py': 3,
    'is-a-financialadvisor.com': 3,
    'gov.cn': 0,
    'bg': 2,
    'lv': 2,
    'in.rs': 3,
    'edu.my': 1,
    'k12.wi.us': 0,
    'asn.au': 1,
    'guru': 3,
    'org.nz': 1,
    'yolasite.com': 2,
    'vn.ua': 4,
    'co.tz': 3,
    'com.pk': 4,
    'kr': 1,
    'tj': 3,
    'so': 3,
    'gen.tr': 2,
    'ac': 2,
    'vu': 3,
    'la': 2,
    'vic.edu.au': 1,
    'go.th': 1,
    'kinghost.net': 2,
    'myqnapcloud.com': 3,
    'edu': 1,
    'gob.mx': 0,
    'edu.pk': 1,
    'kutno.pl': 2,
    'space': 3,
    'ne.jp': 1,
    'blogspot.ca': 3,
    'msk.ru': 5,
    'net.ma': 3,
    'dyndns-web.com': 3,
    'ac.ke': 1,
    'gob.pe': 0,
    'com.sa': 2,
    'org.mk': 3,
    'org.ar': 2,
    'boldlygoingnowhere.org': 3,
    'co.ua': 4,
    'xyz': 3,
    'jelastic.dogado.eu': 2,
    'ga': 4,
    'cat': 2,
    'sg': 2,
    'cool': 3,
    'blogspot.com.au': 3,
    'gm': 2,
    'co.ke': 3,
    'gs': 2,
    'ps': 3,
    'cf': 4,
    'pro': 3,
    'sx': 3,
    'com.eg': 3,
    'hm': 2,
    'myjino.ru': 5,
    'art.br': 1,
    'hr': 2,
    'biz.tr': 2,
    'od.ua': 4,
    'af': 2,
    'pn': 3,
    'co.ma': 3,
    'net.mx': 3,
    'cx': 3,
    'xn--p1ai': 5,
    'ws': 3,
    'nf': 3,
    's3-eu-west-1.amazonaws.com': 2,
    'help': 3,
    'com.ng': 4,
    'tf': 3,
    'tn': 3,
    'edu.kh': 1,
    'ad': 1,
    'adm.br': 1,
    'googlecode.com': 2,
    'host': 3,
    'com.do': 3,
    'blogspot.in': 3,
    'org.ru': 5,
    'edu.rs': 1,
    'university': 1,
    'ma': 3,
    'my': 3,
    'org.in': 3,
    'bs.it': 1,
    'blogspot.nl': 3,
    'com.pt': 2,
    'zj.cn': 5,
    'ac.in': 1,
    'org.ph': 3,
    'or.kr': 1,
    'or.tz': 3,
    'id.au': 1,
    'ae': 1,
    'org.zm': 3,
    'gov.np': 0,
    'lowicz.pl': 2,
    'edu.ec': 1,
    'sa': 2,
    'gov.sa': 0,
    'nr': 3,
    'in.th': 1,
    'me.ke': 3,
    'com.np': 3,
    'edu.mx': 1,
    'org.rs': 2,
    'name.my': 3,
    'poznan.pl': 2,
    'hk': 1,
    'li': 1,
    'party': 3,
    'no-ip.info': 3,
    'org.py': 3,
    'thruhere.net': 3,
    'lk': 2,
    'net.in': 3,
    'adv.br': 1,
    'no-ip.org': 3,
    'club': 3,
    's3-website-us-east-1.amazonaws.com': 2,
    'inf.br': 1,
    'mk': 3,
    'rw': 3,
    'vg': 3,
    'appspot.com': 2,
    'com.uy': 3,
    'net.tw': 2,
    'lutsk.ua': 4,
    'ftpaccess.cc': 3,
    'top': 3,
    'group': 3,
    'site': 3,
    'nyc': 2,
    'duckdns.org': 3,
    'casacam.net': 2,
    'icu': 4,
    'one': 3,
    'ba': 3,
    'ml': 4,
    'wn.r.appspot.com': 2,
    'uc.r.appspot.com': 2,
    'buzz': 3,
    'work': 3,
    'my.id': 3,
    'gr.jp': 1,
    'online': 3,
    'com.ru': 5,
    'bar': 3,
    'desa.id': 3,
    'fun': 3,
    'ddnslive.com': 3,
    'ddnsfree.com': 3,
    'gb.net': 2,
    'dnsup.net': 3,
    '64-b.it': 2,
    'tcp4.me': 3,
    'id': 3,
    'gq': 4,
    'glitch.me': 3,
    'gd': 3,
    'cloudaccess.host': 2,
    'app': 2,
    'store': 2,
    'ue.r.appspot.com': 2,
    'business': 2,
    'services': 2,
    'ms': 2,
    'ru.com': 5,
    'gotdns.ch': 2,
    'email': 3,
    'monster': 3,
    'sa-east-1.elasticbeanstalk.com': 2,
    'dynv6.net': 3,
    'cloud-fr1.unispace.io': 2,
    'webredirect.org': 3,
    'navy': 2,
    'army': 2,
    'med.br': 1,
    'tw': 2,
    'ooguy.com': 3,
    'gov.ar': 0,
    'domains': 2,
    'blog': 3,
    'rj.r.appspot.com': 2,
    'shop': 3,
    'bounceme.net': 3,
    'ddnsgeek.com': 3,
    'link': 2,
    'com.hr': 2,
    'accesscam.org': 3,
    'ddns.net': 3,
    'cluster028.hosting.ovh.net': 2,
    'live': 2,
    'gt': 2,
    'page': 2,
    'press': 2,
    'nz': 1,
    'ltd': 3,
    'net.za': 3,
    'sh': 2,
    'for-more.biz': 3,
    'jdevcloud.com': 3,
    'go.tz': 1,
    'fo': 2,
    'org.pk': 4,
    'sytes.net': 3,
    'web.app': 2,
    'sn': 2,
    'el.r.appspot.com': 2,
    'is-a-designer.com': 2,
    'website': 3,
    'serveirc.com': 3,
    'digital': 2,
    'bz': 3,
    'nn.r.appspot.com': 2,
    'cloud': 2,
    'do': 2,
    'uk': 1,
    'mywire.org': 3,
    'br': 1,
    'ovh': 2,
    'tech': 2,
    'netlify.app': 2,
    'gl': 3,
    'firebaseapp.com': 2,
    'azurewebsites.net': 2,
    'company': 2,
    'am': 2,
    'uk.com': 3,
    'video': 2,
    'df.r.appspot.com': 2,
    'is-slick.com': 2,
    'tv.br': 1,
    'team': 2,
    'ng': 4,
    'krakow.pl': 2,
    'oa.r.appspot.com': 2,
    'wixsite.com': 3,
    'com.sv': 3,
    'edu.hk': 1,
    'gle': 2,
    'com.bd': 3,
    'studio': 2,
    's3.ap-northeast-2.amazonaws.com': 2,
    'is-a-hard-worker.com': 2,
    'pp.ua': 4,
    'mcdir.ru': 5,
    'rest': 2,
    'redirectme.net': 3,
    'events': 2,
    'life': 2,
    'blogspot.rs': 3,
    'loan': 3,
    'edu.vn': 1,
    'casa': 2,
    'ai': 2,
    'rocks': 3,
    'bt': 2,
    'net.ar': 3,
    'org.ua': 4,
    'gdn': 3,
    'gov.la': 0,
    'art': 2,
    'today': 3,
    'gob.sv': 0,
    'mcpre.ru': 5,
    'vip': 3,
    'technology': 2,
    'wpdevcloud.com': 2,
    'best': 3,
    'click': 3,
    'tools': 2,
    'sm': 2,
    'org.pl': 2,
    'za.net': 3,
    'cm': 4,
    'com.gh': 3,
    'qa': 2,
    'pm': 3,
    'edu.ng': 1,
    'world': 2,
    'repl.co': 2,
    'cam': 3,
    'org.np': 3,
    'herokuapp.com': 2,
    'mp': 3,
    'com.gt': 3,
    'edu.ar': 1,
    'pp.ru': 5,
    'edu.af': 1,
    'srv.br': 2,
    'support': 3,
    'solutions': 3,
    'sch.id': 1,
    'house': 3,
    'b.br': 2,
    'bid': 3,
    'blog.br': 2,
    'mypi.co': 3,
    'ec2-3-82-210-25.compute-1.amazonaws.com': 2,
    'cloudfront.net': 2,
    'edu.np': 1,
    'synology.me': 2,
    'blogspot.be': 3,
    'edu.ua': 1,
    'mk.ua': 4,
    'dp.ua': 4,
    'itau': 1,
    'london' : 3,
    'fm' :	2,
    'blogspot.gr' :	3,
    'radio.br' :	1,
    're' :	2,
    'org.mx' :	3,
    'k12.mo.us' :	1,
    's3-ap-southeast-1.amazonaws.com' :	2,
    'kalisz.pl' :	2,
    'uni5.net' :	2,
    'pr' :	2,
    'kim'	: 3,
    'gg' :	3,
    'fg.it' :	1,
    'org.gr' :	2,
    'cash' :	3,
    'repl.run' :	2,
    'com.kz' :	4,
    'akadns.net' : 	2,
    'biz.ua' :	3,
    'go.ug' :	3,
    'ci' : 	3,
    'gitlab.io' :	2,
    'al' :	2,
    'uy' :	1,
    'edu.ph' :	1,
    'cheap' :	3,
    'dreamhosters.com' :	2,
    'net.ng' :	3,
    'spb.ru' :	5,
    'edu.tr' :	1,
    'ag' :	2,
    'cloud.goog' :	2,
    'cloudns.asia' :	3,
    'github.io' :	2,
    'expert' :	3,
    'lviv.ua' :	3,
    'as' :	1,
    'net.nz' :	1,
    'wf' :	3,
    'sfo2.digitaloceanspaces.com' :	2,
    'ec' :	2,
    'blogspot.ru' :	5,
    'co.ao' :	3,
    'tl' :	3,
    'blogspot.it' :	3,
    'bf' :	2,
    'stargard.pl' :	2,
    'mu' :	3,
    'biz.pl' :	3,
    'gov.kg' :	0,
    'ngrok.io' :	3,
    'jellybean.jp' :	2,
    'ams3.digitaloceanspaces.com' :	2,
    'download' :	4,
    'ninja' :	4,
    'red' :	3,
    'hopto.org' :	3,
    'azonaws.com' :	2,
    'gratis' :	3,
    'win' :	3,
    'ilawa.pl' :	2,
    'org.my' :	2,
    'whitesnow.jp' :	1,
    'lovesick.jp' :	1,
    'namaste.jp' :	1,
    'fem.jp' :	1,
    'cluster020.hosting.ovh.net' :	2,
    'com.de' :	3,
    'myftp.biz' :	3,
    'gov.pk' :	0,
    'llc' :	2,
    'eurodir.ru' :	5,
    'org.hk' :	2,
    'ht' :	3,
}
# Out:
# [None, 'be', 'net', 'com', 'nl', 'de', 'hu', 'co', 'it', 'ac.uk', 'com.br', 'ir', 'org', 'pl', 'gr', 'ru', 'com.ua', 'info', 'vn', 'ro', 'cl', 'com.ar', 'ca', 'sk', 'es', 'co.uk', 'si', 'biz', 'net.br', 'ind.br', 'kiev.ua', 'net.vn', 'cc', 'at', 'tv', 'eu', 'cn', 'com.vn', 'com.my', 'cz', 'com.au', 'jp', 'dk', 'fr', 'co.za', 'lt', 'md', 'fi', 'blogspot.com', 'co.id', 'edu.co', 'com.tr', 'in', 'org.au', 'se', 'ch', 'com.pl', 'ee', 'com.sg', 'us', 'bn.it', 'com.cn', 'gov.br', 'ph', 'mx', 'co.kr', 'net.ua', 'k12.tr', 'gov.uk', 'com.gr', 'asia', 'co.th', 'ua', 'info.pl', 'com.mx', 'no', 'pt', 'co.zw', 'ie', 'co.nz', 'kz', 'org.uk', 'nu', 'eu.com', 'is', 'nhs.uk', 'lu', 'edu.pe', 'rs', 'com.cy', 'uz', 'org.cn', 'org.za', 'pe', 'pk', 'in.ua', 'gov.gr', 'org.br', 'is-a-libertarian.com', 'com.co', 'com.ba', 'com.bo', 'cv', 'ab.ca', 'travel.pl', 'com.pe', 'altervista.org', 'io', 'to', 'az', 'com.tw', 'blogspot.co.uk', 'org.tr', 'im', 'ge', 'co.jp', 'su', 'edu.au', 'co.il', 'co.rs', 'com.hk', 
# ...

# %%
# Extractions of features

#Length Of Url
urldata['url_length'] = urldata['url'].apply(lambda i: len(str(i)))

#Length of Hostname
urldata['hostname_length'] = urldata['url'].apply(lambda i: len(urlparse(i).netloc))
#Length Of Path
urldata['path_length'] = urldata['url'].apply(lambda i: len(urlparse(i).path))

#Length Of First Directory
def fd_length(url):
    urlpath= urlparse(url).path
    try:
        return len(urlpath.split('/')[1])
    except:
        return 0

urldata['fd_length'] = urldata['url'].apply(lambda i: fd_length(i))


#Dangerosity Of Top Level Domain

for index, row in urldata.iterrows():
    tld = get_tld(row['url'],fail_silently=True)
    if tld in tld_dangerosity:
        urldata.at[index, 'tld_dangerosity'] = tld_dangerosity[tld]
    else:
        urldata.at[index, 'tld_dangerosity'] = 3


#Count Of '-'
urldata['count-'] = urldata['url'].apply(lambda i: i.count('-'))

#Count Of '@'
urldata['count@'] = urldata['url'].apply(lambda i: i.count('@'))

#Count Of '?'
urldata['count?'] = urldata['url'].apply(lambda i: i.count('?'))

#Count Of '%'
urldata['count%'] = urldata['url'].apply(lambda i: i.count('%'))

#Count Of '.'
urldata['count.'] = urldata['url'].apply(lambda i: i.count('.'))

#Count Of '='
urldata['count='] = urldata['url'].apply(lambda i: i.count('='))

#Count Of 'http'
urldata['count-http'] = urldata['url'].apply(lambda i : i.count('http'))
urldata['count-https'] = urldata['url'].apply(lambda i : i.count('https'))

#Count Of 'www'
urldata['count-www'] = urldata['url'].apply(lambda i: i.count('www'))

#Count Of Digits
def digit_count(url):
    digits = 0
    for i in url:
        if i.isnumeric():
            digits = digits + 1
    return digits
urldata['count-digits']= urldata['url'].apply(lambda i: digit_count(i))

#Count Of Letters
def letter_count(url):
    letters = 0
    for i in url:
        if i.isalpha():
            letters = letters + 1
    return letters
urldata['count-letters']= urldata['url'].apply(lambda i: letter_count(i))

#Count Of Number Of Directories
def no_of_dir(url):
    urldir = urlparse(url).path
    return urldir.count('/')
urldata['count_dir'] = urldata['url'].apply(lambda i: no_of_dir(i))

#Use of IP or not
def having_ip_address(url):
    match = re.search(
        '(([01]?\\d\\d?|2[0-4]\\d|25[0-5])\\.([01]?\\d\\d?|2[0-4]\\d|25[0-5])\\.([01]?\\d\\d?|2[0-4]\\d|25[0-5])\\.'
        '([01]?\\d\\d?|2[0-4]\\d|25[0-5])\\/)|'  # IPv4
        '((0x[0-9a-fA-F]{1,2})\\.(0x[0-9a-fA-F]{1,2})\\.(0x[0-9a-fA-F]{1,2})\\.(0x[0-9a-fA-F]{1,2})\\/)' # IPv4 in hexadecimal
        '(?:[a-fA-F0-9]{1,4}:){7}[a-fA-F0-9]{1,4}', url)  # Ipv6
    if match:
        # print match.group()
        return -1
    else:
        # print 'No matching pattern found'
        return 1
urldata['use_of_ip'] = urldata['url'].apply(lambda i: having_ip_address(i))

#Use of Shortening URL or not
def shortening_service(url):
    match = re.search('bit\.ly|goo\.gl|shorte\.st|go2l\.ink|x\.co|ow\.ly|t\.co|tinyurl|tr\.im|is\.gd|cli\.gs|'
                      'yfrog\.com|migre\.me|ff\.im|tiny\.cc|url4\.eu|twit\.ac|su\.pr|twurl\.nl|snipurl\.com|'
                      'short\.to|BudURL\.com|ping\.fm|post\.ly|Just\.as|bkite\.com|snipr\.com|fic\.kr|loopt\.us|'
                      'doiop\.com|short\.ie|kl\.am|wp\.me|rubyurl\.com|om\.ly|to\.ly|bit\.do|t\.co|lnkd\.in|'
                      'db\.tt|qr\.ae|adf\.ly|goo\.gl|bitly\.com|cur\.lv|tinyurl\.com|ow\.ly|bit\.ly|ity\.im|'
                      'q\.gs|is\.gd|po\.st|bc\.vc|twitthis\.com|u\.to|j\.mp|buzurl\.com|cutt\.us|u\.bb|yourls\.org|'
                      'x\.co|prettylinkpro\.com|scrnch\.me|filoops\.info|vzturl\.com|qr\.net|1url\.com|tweez\.me|v\.gd|'
                      'tr\.im|link\.zip\.net',
                      url)
    if match:
        return -1
    else:
        return 1

urldata['short_url'] = urldata['url'].apply(lambda i: shortening_service(i))

urldata.head()
# Out:
#                                                  url        type  url_length  \
# 0                                   br-icloud.com.br    phishing          16
# 1                mp3raid.com/music/krizz_kaliko.html      benign          35
# 2                    bopsecrets.org/rexroth/cr/1.htm      benign          31
# 3  http://www.garage-pirenne.be/index.php?option=...  defacement          88
# 4  http://adventure-nicaragua.net/index.php?optio...  defacement         235
#
#    hostname_length  path_length  fd_length  tld_dangerosity  count-  count@  \
# 0                0           16          0              3.0       1       0
# 1                0           35          5              3.0       0       0
# 2                0           31          7              3.0       0       0
# 3               21           10          9              2.0       1       0
# 4               23           10          9              3.0       1       0
#
# ...

# %%
updated_file_path = "/content/updated_malicious_phish1.csv"
urldata.to_csv(updated_file_path, index=False)
